# %% [markdown]
# # ANÁLISE LOTOFÁCIL  (Alvo de popularidade simulado)

# %%
# %cd ..
# Out:
# c:\Users\Vedovi\lotofacil\lotofacil

# %% [markdown]
# ### Importações

# %%
import pandas as pd

from modelo.popularidade import preparar_combinacoes
from modelo.popularidade import treinar_modelo_popularidade
from modelo.popularidade import gerar_jogos_pouco_populares
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 from modelo.popularidade import preparar_combinacoes
#       4 from modelo.popularidade import treinar_modelo_popularidade
#       5 from modelo.popularidade import gerar_jogos_pouco_populares
#
# ModuleNotFoundError: No module named 'modelo'

# %%
caminho_csv = "../combinacoes/combinacoes.csv"  # caminho relativo a partir de analises/

combinacoes = pd.read_csv(caminho_csv, sep=";")  # ajuste sep se precisar
combinacoes.head()
