# %%
from dados.apostas import simular_apostas_exemplo

apostas = simular_apostas_exemplo()
apostas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from dados.apostas import simular_apostas_exemplo
#       3 apostas = simular_apostas_exemplo()
#       4 apostas
#
# ModuleNotFoundError: No module named 'dados'
